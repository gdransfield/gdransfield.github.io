# %%
from gui import planets_path, BD_path, tab, button, out, button1

display(planets_path, BD_path, tab, button, out, button1)
# Out:
# Text(value='planet_fluxes.txt', description='Path to planet database:', placeholder='Paste here', style=Descri…
# Text(value='bd_mags.txt', description='Path to brown dwarf database:', placeholder='Paste here', style=Descrip…
# ...
# Button(button_style='success', description='Plot Diagram', icon='check', style=ButtonStyle(), tooltip='Click m…
# Output(layout=Layout(border='1px solid black'))
# Button(description='Clear All', style=ButtonStyle())
